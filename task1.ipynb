# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !kaggle competitions download -c titanic
# Out:
# /bin/bash: kaggle: command not found

# %%
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 48.8 MB/s eta 0:00:000:00:01
# ...
#   Attempting uninstall: mypy
#     Found existing installation: mypy 1.11.2
#     Uninstalling mypy-1.11.2:
#       Successfully uninstalled mypy-1.11.2
#   Attempting uninstall: black
#     Found existing installation: black 24.8.0
#     Uninstalling black-24.8.0:
#       Successfully uninstalled black-24.8.0
# ...

# %%
# !kaggle competitions download -c titanic
# Out:
# Could not find kaggle.json. Make sure it's located in /home/csl-4/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !kaggle datasets download -d sparshchaudhari/bsiotr-dsbda-8
# !unzip bsiotr-dsbda-8.zip -d bsiotr_dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sparshchaudhari/bsiotr-dsbda-8
# License(s): unknown
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# unzip:  cannot find or open bsiotr-dsbda-8.zip, bsiotr-dsbda-8.zip.zip or bsiotr-dsbda-8.zip.ZIP.

# %%
# !kaggle datasets download -d sparshchaudhari/bsiotr-dsbda-8
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sparshchaudhari/bsiotr-dsbda-8
# License(s): unknown
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d sparshchaudhari/bsiotr-dsbda-8
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sparshchaudhari/bsiotr-dsbda-8
# License(s): unknown
# ...
#   0%|                                               | 0.00/7.37k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 7.37k/7.37k [00:00<00:00, 26.6MB/s]

# %%
# !unzip bsiotr-dsbda-8.zip -d bsiotr_dataset
# Out:
# Archive:  bsiotr-dsbda-8.zip
#   inflating: bsiotr_dataset/titanic.csv

# %%
import pandas as pd
import os

for f in os.listdir('bsiotr_dataset'):
    print(f)

df = pd.read_csv('bsiotr_dataset/titanic.csv')
df.head()
# Out:
# titanic.csv
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print("Missing values in each column:\n", df.isnull().sum())
# Out:
# Missing values in each column:
#  survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print(df.describe(include='all'))
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
print("DataFrame Shape:", df.shape)  # (rows, columns)
# Out:
# DataFrame Shape: (891, 15)

# %%
print(df.dtypes)
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object
