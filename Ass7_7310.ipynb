# %%
pip install nltk scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/csl-4/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/csl-4/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/csl-4/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/csl-4/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
document = """
Text analytics is the process of converting unstructured text into meaningful data.
It helps in extracting useful insights from text data using NLP techniques.
"""

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(document)
print(tokens)
# Out:
# ['Text', 'analytics', 'is', 'the', 'process', 'of', 'converting', 'unstructured', 'text', 'into', 'meaningful', 'data', '.', 'It', 'helps', 'in', 'extracting', 'useful', 'insights', 'from', 'text', 'data', 'using', 'NLP', 'techniques', '.']

# %%
from nltk import pos_tag

pos_tags = pos_tag(tokens)
print(pos_tags)
# Out:
# [('Text', 'NN'), ('analytics', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('converting', 'VBG'), ('unstructured', 'JJ'), ('text', 'NN'), ('into', 'IN'), ('meaningful', 'JJ'), ('data', 'NNS'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('in', 'IN'), ('extracting', 'VBG'), ('useful', 'JJ'), ('insights', 'NNS'), ('from', 'IN'), ('text', 'NN'), ('data', 'NNS'), ('using', 'VBG'), ('NLP', 'NNP'), ('techniques', 'NNS'), ('.', '.')]

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print(filtered_tokens)
# Out:
# ['Text', 'analytics', 'process', 'converting', 'unstructured', 'text', 'meaningful', 'data', '.', 'helps', 'extracting', 'useful', 'insights', 'text', 'data', 'using', 'NLP', 'techniques', '.']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words)
# Out:
# ['text', 'analyt', 'process', 'convert', 'unstructur', 'text', 'meaning', 'data', '.', 'help', 'extract', 'use', 'insight', 'text', 'data', 'use', 'nlp', 'techniqu', '.']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words)
# Out:
# ['Text', 'analytics', 'process', 'converting', 'unstructured', 'text', 'meaningful', 'data', '.', 'help', 'extracting', 'useful', 'insight', 'text', 'data', 'using', 'NLP', 'technique', '.']

# %%
from collections import Counter

tf = Counter(lemmatized_words)
print(tf)
# Out:
# Counter({'text': 2, 'data': 2, '.': 2, 'Text': 1, 'analytics': 1, 'process': 1, 'converting': 1, 'unstructured': 1, 'meaningful': 1, 'help': 1, 'extracting': 1, 'useful': 1, 'insight': 1, 'using': 1, 'NLP': 1, 'technique': 1})

# %%
documents = [
    "Text analytics converts text into meaningful data",
    "NLP techniques help in text analytics",
    "Text data gives useful insights"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
print(tfidf_matrix.toarray())
# Out:
# ['analytics' 'converts' 'data' 'gives' 'help' 'insights' 'meaningful'
#  'nlp' 'techniques' 'text' 'useful']
# [[0.3564574  0.46869865 0.3564574  0.         0.         0.
#   0.46869865 0.         0.         0.55364194 0.        ]
#  [0.38376993 0.         0.         0.         0.50461134 0.
#   0.         0.50461134 0.50461134 0.29803159 0.        ]
#  [0.         0.         0.38376993 0.50461134 0.         0.50461134
#   0.         0.         0.         0.29803159 0.50461134]]

# %%
print("TF-IDF Representation:")
words = vectorizer.get_feature_names_out()
for i, word in enumerate(words):
    print(f"{word}: {tfidf_matrix[0, i]:.4f}")
# Out:
# TF-IDF Representation:
# analytics: 0.3565
# converts: 0.4687
# data: 0.3565
# gives: 0.0000
# help: 0.0000
# insights: 0.0000
# meaningful: 0.4687
# nlp: 0.0000
# techniques: 0.0000
# text: 0.5536
# useful: 0.0000
