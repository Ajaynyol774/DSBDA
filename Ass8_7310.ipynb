# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Make plots appear inside notebook
# %matplotlib inline

# Set style for better visuals
sns.set_style("whitegrid")
sns.set_context("talk") # makes text bigger

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/titanic_data.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.shape          # number of rows and columns
titanic.info()         # types and missing values
titanic.describe()     # statistical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
data.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(np.mean(data['Age']))

# %%
data['Cabin'] = data['Cabin'].fillna(data['Cabin'].mode()[0])

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.countplot(x='Survived', data=data)
plt.show()

# %%
sns.countplot(x='Pclass', data=data)
plt.show()

# %%
sns.countplot(x='Embarked' , data=data)
plt.show()

# %%
sns.countplot(x='Sex' , data=data)
plt.show()

# %%
sns.boxplot(x='Age' , data=data)
plt.show()

# %%
sns.boxplot(x='Fare' , data=data)
plt.show()

# %%
sns.boxplot(x='Pclass' , data=data)
plt.show()

# %%
sns.boxplot(x='SibSp' , data=data)
plt.show()

# %%
g = sns.catplot(x='Pclass', y='Age', data=data, kind='box')

plt.show()

# %%
g = sns.catplot(x= 'Pclass', y = 'Fare', data=data, kind = 'strip')
plt.show()

# %%
g = sns.catplot(x= 'Sex', y = 'Fare', data=data, kind = 'strip')
plt.show()

# %%
g = sns.catplot(x= 'Sex', y = 'Age', data=data, kind = 'strip')
plt.show()

# %%
g = sns.pairplot(data)
plt.show()

# %%
sns.scatterplot(x = 'Fare', y = 'Pclass', hue = 'Survived', data = data)
plt.show()

# %%
sns.scatterplot(x = 'Survived', y = 'Fare', data = data)
plt.show()

# %%
sns.displot(data['Age'], kde=True)
plt.show()

# %%
sns.displot(data['Fare'], kde=True)
plt.show()

# %%
sns.jointplot(x = "Survived", y = "Fare", kind = "scatter", data = data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numeric columns only
numeric_data = data.select_dtypes(include=['number'])

# Compute correlation
tc = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(tc, cmap="YlGnBu", annot=True, fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
sns.catplot(x='Pclass', y='Fare', data=data, kind='bar')
plt.show()
